# %%
import pandas as pd

# %%
import client.clientpy3 as cl

# %%
# There is just run command which needs to be used

# %%
cl.run('1','1','STATUS')
# Out:
# STATUS_OUT 5000.0 5000.0 0.0 0.0  MINES 0 PLAYERS 26 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 5000.0 5000.0 0.0 0.0 BOMBS 0 WORMHOLES0

# %%
cl.run('1','1','CONFIGURATIONS')
# Out:
# CONFIGURATIONS_OUT MAPWIDTH 10000 MAPHEIGHT 10000 CAPTURERADIUS 40.0 VISIONRADIUS 150.0 FRICTION 0.99 BRAKEFRICTION 0.987 BOMBPLACERADIUS 50.0 BOMBEFFECTRADIUS 15.0 BOMBDELAY 100 BOMBPOWER 15.0 SCANRADIUS 125.0 SCANDELAY 100

# %%
cl.run('1','1','ACCELERATE 0 1')
# Out:
# ACCELERATE_OUT DONE

# %%
cl.run('2','2','STATUS')
# Out:
# STATUS_OUT 1164.8717124581162 5000.0 9.86728287542001 0.0  MINES 0 PLAYERS 0 BOMBS 0 WORMHOLES0

# %%
for i in range(10):
    cl.run('2','2',"STATUS")
    cl.run('2','3','BOMB ')
# Out:
# STATUS_OUT 7229.100000004917 5000.0 9.900000000000043 0.0  MINES 0 PLAYERS 0 BOMBS 0 WORMHOLES0
# ERROR uknown error
# STATUS_OUT 7398.2500000049295 5000.0 9.900000000000043 0.0  MINES 0 PLAYERS 0 BOMBS 0 WORMHOLES0
# ERROR uknown error
# ...
